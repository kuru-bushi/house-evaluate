# %%
import numpy as np
# Out:
# 'base (Python 3.10.6)' でセルを実行するには、 ipykernel パッケージが必要です。
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Python 環境の作成</a> および必要なパッケージ。
#
# または、次のコマンドを使用して 'ipykernel' をインストールします: 'conda install -n base ipykernel --update-deps --force-reinstall'
